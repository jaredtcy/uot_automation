# %%
'/Users/jared/.pyenv/versions/3.11.0/bin/python -m pip install ipykernel -U --force-reinstall'
# Out:
# '/Users/jared/.pyenv/versions/3.11.0/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
pip install pandas
# Out:
# ...
#
# [notice] A new release of pip available: 22.3 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
import numpy as np

# %%
dummy_dataframe = pd.DataFrame({'col1':[1,2,3,4], 'col2':[8,7,9,6]})

# %%
dummy_dataframe
# Out:
#    col1  col2
# 0     1     8
# 1     2     7
# 2     3     9
# 3     4     6

# %%
dummy_series = pd.Series([1,7,8,9,6])

# %%
type(dummy_dataframe)
# Out:
# pandas.core.frame.DataFrame

# %%
type(dummy_dataframe['col1'])
# Out:
# pandas.core.series.Series

# %%
new_list = dummy_dataframe['col1'].to_list()

# %%
new_list.extend([5,4,7,8])

# %%
updated_dataframe = pd.concat([pd.Series(new_list),dummy_dataframe['col2']], axis=1)

# %%
updated_dataframe.columns = ['col1','col2']

# %%
updated_dataframe
# Out:
#    col1  col2
# 0     1   8.0
# 1     2   7.0
# 2     3   9.0
# 3     4   6.0
# 4     5   NaN
# 5     4   NaN
# 6     7   NaN
# 7     8   NaN

# %%
dummy_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   col1    4 non-null      int64
#  1   col2    4 non-null      int64
# dtypes: int64(2)
# memory usage: 192.0 bytes

# %%
updated_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   col1    8 non-null      int64
#  1   col2    4 non-null      float64
# dtypes: float64(1), int64(1)
# memory usage: 256.0 bytes

# %%
dummy_dataframe.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
dummy_dataframe.columns
# Out:
# Index(['col1', 'col2'], dtype='object')

# %%
dummy_dataframe.axes
# Out:
# [RangeIndex(start=0, stop=4, step=1), Index(['col1', 'col2'], dtype='object')]

# %%
dummy_dataframe.head()
# Out:
#    col1  col2
# 0     1     8
# 1     2     7
# 2     3     9
# 3     4     6

# %%
dummy_dataframe.tail()
# Out:
#    col1  col2
# 0     1     8
# 1     2     7
# 2     3     9
# 3     4     6

# %%
dummy_dataframe.describe()
# Out:
#            col1      col2
# count  4.000000  4.000000
# mean   2.500000  7.500000
# std    1.290994  1.290994
# min    1.000000  6.000000
# 25%    1.750000  6.750000
# 50%    2.500000  7.500000
# 75%    3.250000  8.250000
# max    4.000000  9.000000

# %%
#isolating a specific column
dummy_dataframe.col1
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: col1, dtype: int64

# %%
dummy_dataframe['col1']
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: col1, dtype: int64

# %%
#iloc/loc function helps to isolate the row
#iloc = index location value of the index
#loc = location of the actual value
dummy_dataframe.iloc[2].loc['col1']
# Out:
# 3

# %%
dummy_dataframe
# Out:
#    col1  col2
# 0     1     8
# 1     2     7
# 2     3     9
# 3     4     6

# %%
dummy_dataframe.index = ['val1','val2','val3','val4']

# %%
dummy_dataframe
# Out:
#       col1  col2
# val1     1     8
# val2     2     7
# val3     3     9
# val4     4     6

# %%
dummy_dataframe.iloc[0].loc['col2']
# Out:
# 8

# %%
dummy_dataframe.loc['val1']
# Out:
# col1    1
# col2    8
# Name: val1, dtype: int64

# %%
dummy_dataframe.iloc[1,1]
# Out:
# 7

# %%
dummy_dataframe.iloc[0:2,1] #slicing a range of rows , and the column in position 1 (second position) #slicing gives u row and column name separated by "," so A,B is row A and column B
# Out:
# val1    8
# val2    7
# Name: col2, dtype: int64

# %%
dummy_dataframe.loc[['val1','val3'],['col1','col2']] #slicing selected rows/columns - we need to pass a list of conditions, thus 2 sets of brackets
# Out:
#       col1  col2
# val1     1     8
# val3     3     9

# %%
dummy_dataframe.iloc[[0,2],[0,1]] #same as above, but this is slicing based on position
# Out:
#       col1  col2
# val1     1     8
# val3     3     9

# %%
#Can also copy the raw link (From github go to raw then in url then just paste the link in the '')
orders=pd.read_csv('customer_orders.csv')

# %%
orders
# Out:
#     order_date  customer_id            name             email  product_id  \
# 0   2022-01-01         1001      John Adams    john@email.com          12
# 1   2022-01-02         1002     Jorden Haas  jorden@email.com          13
# 2   2022-01-03         1001      John Adams    john@email.com          13
# 3   2022-01-04         1002     Jorden Haas  jorden@email.com          14
# 4   2022-01-05         1003   Pierce Glover  pierce@email.com          12
# 5   2022-01-06         1001      John Adams    john@email.com          14
# 6   2022-01-07         1002     Jorden Haas  jorden@email.com          14
# 7   2022-01-08         1003   Pierce Glover  pierce@email.com          13
# 8   2022-01-09         1004  Carly Copeland   carly@email.com          12
# 9   2022-01-10         1002     Jorden Haas  jorden@email.com          12
# 10  2022-01-11         1003   Pierce Glover  pierce@email.com          13
# 11  2022-01-12         1004  Carly Copeland               NaN          15
# ...

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   order_date       14 non-null     object
#  1   customer_id      14 non-null     int64
#  2   name             14 non-null     object
#  3   email            12 non-null     object
#  4   product_id       14 non-null     int64
#  5   brand            14 non-null     object
#  6   next_action      0 non-null      float64
#  7   delivery_date    0 non-null      float64
#  8   delivery_route   0 non-null      float64
#  9   account_manager  0 non-null      float64
# dtypes: float64(4), int64(2), object(4)
# memory usage: 1.2+ KB

# %%
orders.head()
# Out:
#    order_date  customer_id           name             email  product_id  \
# 0  2022-01-01         1001     John Adams    john@email.com          12
# 1  2022-01-02         1002    Jorden Haas  jorden@email.com          13
# 2  2022-01-03         1001     John Adams    john@email.com          13
# 3  2022-01-04         1002    Jorden Haas  jorden@email.com          14
# 4  2022-01-05         1003  Pierce Glover  pierce@email.com          12
#
#     brand  next_action  delivery_date  delivery_route  account_manager
# 0     ABC          NaN            NaN             NaN              NaN
# 1  Brand2          NaN            NaN             NaN              NaN
# 2  Brand2          NaN            NaN             NaN              NaN
# 3     ABC          NaN            NaN             NaN              NaN
# 4     ABC          NaN            NaN             NaN              NaN

# %%
orders.tail()
# Out:
#     order_date  customer_id            name             email  product_id  \
# 9   2022-01-10         1002     Jorden Haas  jorden@email.com          12
# 10  2022-01-11         1003   Pierce Glover  pierce@email.com          13
# 11  2022-01-12         1004  Carly Copeland               NaN          15
# 12  2022-01-13         1003   Pierce Glover  pierce@email.com          12
# 13  2022-01-14         1004  Carly Copeland               NaN          15
#
#      brand  next_action  delivery_date  delivery_route  account_manager
# 9      ABC          NaN            NaN             NaN              NaN
# 10  Brand2          NaN            NaN             NaN              NaN
# 11      DT          NaN            NaN             NaN              NaN
# 12     ABC          NaN            NaN             NaN              NaN
# 13      DT          NaN            NaN             NaN              NaN

# %%
orders[['order_date','name']] # Isolate specific columns
# Out:
#     order_date            name
# 0   2022-01-01      John Adams
# 1   2022-01-02     Jorden Haas
# 2   2022-01-03      John Adams
# 3   2022-01-04     Jorden Haas
# 4   2022-01-05   Pierce Glover
# 5   2022-01-06      John Adams
# 6   2022-01-07     Jorden Haas
# 7   2022-01-08   Pierce Glover
# 8   2022-01-09  Carly Copeland
# 9   2022-01-10     Jorden Haas
# 10  2022-01-11   Pierce Glover
# 11  2022-01-12  Carly Copeland
# 12  2022-01-13   Pierce Glover
# 13  2022-01-14  Carly Copeland

# %%
orders.iloc[[10,13]]
# Out:
#     order_date  customer_id            name             email  product_id  \
# 10  2022-01-11         1003   Pierce Glover  pierce@email.com          13
# 13  2022-01-14         1004  Carly Copeland               NaN          15
#
#      brand  next_action  delivery_date  delivery_route  account_manager
# 10  Brand2          NaN            NaN             NaN              NaN
# 13      DT          NaN            NaN             NaN              NaN

# %%
#Note that set index is not a inplace change so it is a temporary change. Usually we use this to basically index a certain column and then assign it to a variable etc

orders.set_index('customer_id').loc[1001]
# Out:
#              order_date        name           email  product_id   brand  \
# customer_id
# 1001         2022-01-01  John Adams  john@email.com          12     ABC
# 1001         2022-01-03  John Adams  john@email.com          13  Brand2
# 1001         2022-01-06  John Adams  john@email.com          14     ABC
#
#              next_action  delivery_date  delivery_route  account_manager
# customer_id
# 1001                 NaN            NaN             NaN              NaN
# 1001                 NaN            NaN             NaN              NaN
# 1001                 NaN            NaN             NaN              NaN

# %%
orders.reset_index() #inplace is false. Can set it permanently if want
# Out:
#     index  order_date  customer_id            name             email  \
# 0       0  2022-01-01         1001      John Adams    john@email.com
# 1       1  2022-01-02         1002     Jorden Haas  jorden@email.com
# 2       2  2022-01-03         1001      John Adams    john@email.com
# 3       3  2022-01-04         1002     Jorden Haas  jorden@email.com
# 4       4  2022-01-05         1003   Pierce Glover  pierce@email.com
# 5       5  2022-01-06         1001      John Adams    john@email.com
# 6       6  2022-01-07         1002     Jorden Haas  jorden@email.com
# 7       7  2022-01-08         1003   Pierce Glover  pierce@email.com
# 8       8  2022-01-09         1004  Carly Copeland   carly@email.com
# 9       9  2022-01-10         1002     Jorden Haas  jorden@email.com
# 10     10  2022-01-11         1003   Pierce Glover  pierce@email.com
# 11     11  2022-01-12         1004  Carly Copeland               NaN
# 12     12  2022-01-13         1003   Pierce Glover  pierce@email.com
# ...

# %%
#usually to reset index first and then set index
orders.reset_index().set_index('name')
# Out:
#                 index  order_date  customer_id             email  product_id  \
# name
# John Adams          0  2022-01-01         1001    john@email.com          12
# Jorden Haas         1  2022-01-02         1002  jorden@email.com          13
# John Adams          2  2022-01-03         1001    john@email.com          13
# Jorden Haas         3  2022-01-04         1002  jorden@email.com          14
# Pierce Glover       4  2022-01-05         1003  pierce@email.com          12
# John Adams          5  2022-01-06         1001    john@email.com          14
# Jorden Haas         6  2022-01-07         1002  jorden@email.com          14
# Pierce Glover       7  2022-01-08         1003  pierce@email.com          13
# Carly Copeland      8  2022-01-09         1004   carly@email.com          12
# Jorden Haas         9  2022-01-10         1002  jorden@email.com          12
# Pierce Glover      10  2022-01-11         1003  pierce@email.com          13
# ...

# %%
orders.sort_index()  #By default is smallest to largest
# Out:
#     order_date  customer_id            name             email  product_id  \
# 0   2022-01-01         1001      John Adams    john@email.com          12
# 1   2022-01-02         1002     Jorden Haas  jorden@email.com          13
# 2   2022-01-03         1001      John Adams    john@email.com          13
# 3   2022-01-04         1002     Jorden Haas  jorden@email.com          14
# 4   2022-01-05         1003   Pierce Glover  pierce@email.com          12
# 5   2022-01-06         1001      John Adams    john@email.com          14
# 6   2022-01-07         1002     Jorden Haas  jorden@email.com          14
# 7   2022-01-08         1003   Pierce Glover  pierce@email.com          13
# 8   2022-01-09         1004  Carly Copeland   carly@email.com          12
# 9   2022-01-10         1002     Jorden Haas  jorden@email.com          12
# 10  2022-01-11         1003   Pierce Glover  pierce@email.com          13
# 11  2022-01-12         1004  Carly Copeland               NaN          15
# ...

# %%
orders.sort_index(ascending=False) #Also has inplace argument can set if want
# Out:
#     order_date  customer_id            name             email  product_id  \
# 13  2022-01-14         1004  Carly Copeland               NaN          15
# 12  2022-01-13         1003   Pierce Glover  pierce@email.com          12
# 11  2022-01-12         1004  Carly Copeland               NaN          15
# 10  2022-01-11         1003   Pierce Glover  pierce@email.com          13
# 9   2022-01-10         1002     Jorden Haas  jorden@email.com          12
# 8   2022-01-09         1004  Carly Copeland   carly@email.com          12
# 7   2022-01-08         1003   Pierce Glover  pierce@email.com          13
# 6   2022-01-07         1002     Jorden Haas  jorden@email.com          14
# 5   2022-01-06         1001      John Adams    john@email.com          14
# 4   2022-01-05         1003   Pierce Glover  pierce@email.com          12
# 3   2022-01-04         1002     Jorden Haas  jorden@email.com          14
# 2   2022-01-03         1001      John Adams    john@email.com          13
# ...

# %%
orders.reset_index().set_index('order_date').sort_index(ascending=False).head(5)
#Gives u last 5 record
# Out:
#             index  customer_id            name             email  product_id  \
# order_date
# 2022-01-14     13         1004  Carly Copeland               NaN          15
# 2022-01-13     12         1003   Pierce Glover  pierce@email.com          12
# 2022-01-12     11         1004  Carly Copeland               NaN          15
# 2022-01-11     10         1003   Pierce Glover  pierce@email.com          13
# 2022-01-10      9         1002     Jorden Haas  jorden@email.com          12
#
#              brand  next_action  delivery_date  delivery_route  \
# order_date
# 2022-01-14      DT          NaN            NaN             NaN
# 2022-01-13     ABC          NaN            NaN             NaN
# 2022-01-12      DT          NaN            NaN             NaN
# 2022-01-11  Brand2          NaN            NaN             NaN
# 2022-01-10     ABC          NaN            NaN             NaN
#
#             account_manager
# order_date
# 2022-01-14              NaN
# ...

# %%
list_dates = ['1-1-2022','1-2-2022','1-14-2022']

# %%
sorted(list_dates)
# Out:
# ['1-1-2022', '1-14-2022', '1-2-2022']

# %%
orders['order_date'] = orders['order_date'].astype('datetime64[ns]')

# %%
orders
# Out:
#    order_date  customer_id            name             email  product_id  \
# 0  2022-01-01         1001      John Adams    john@email.com          12
# 1  2022-01-02         1002     Jorden Haas  jorden@email.com          13
# 2  2022-01-03         1001      John Adams    john@email.com          13
# 3  2022-01-04         1002     Jorden Haas  jorden@email.com          14
# 4  2022-01-05         1003   Pierce Glover  pierce@email.com          12
# 5  2022-01-06         1001      John Adams    john@email.com          14
# 6  2022-01-07         1002     Jorden Haas  jorden@email.com          14
# 7  2022-01-08         1003   Pierce Glover  pierce@email.com          13
# 8  2022-01-09         1004  Carly Copeland   carly@email.com          12
# 9  2022-01-10         1002     Jorden Haas  jorden@email.com          12
# 10 2022-01-11         1003   Pierce Glover  pierce@email.com          13
# 11 2022-01-12         1004  Carly Copeland               NaN          15
# ...

# %%
orders['order_date'] = pd.to_datetime(orders['order_date'])

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   order_date       14 non-null     datetime64[ns]
#  1   customer_id      14 non-null     int64
#  2   name             14 non-null     object
#  3   email            12 non-null     object
#  4   product_id       14 non-null     int64
#  5   brand            14 non-null     object
#  6   next_action      0 non-null      float64
#  7   delivery_date    0 non-null      float64
#  8   delivery_route   0 non-null      float64
#  9   account_manager  0 non-null      float64
# dtypes: datetime64[ns](1), float64(4), int64(2), object(3)
# memory usage: 1.2+ KB

# %%
orders[orders['brand'] == 'ABC']
# Out:
#    order_date  customer_id            name             email  product_id  \
# 0  2022-01-01         1001      John Adams    john@email.com          12
# 3  2022-01-04         1002     Jorden Haas  jorden@email.com          14
# 4  2022-01-05         1003   Pierce Glover  pierce@email.com          12
# 5  2022-01-06         1001      John Adams    john@email.com          14
# 6  2022-01-07         1002     Jorden Haas  jorden@email.com          14
# 8  2022-01-09         1004  Carly Copeland   carly@email.com          12
# 9  2022-01-10         1002     Jorden Haas  jorden@email.com          12
# 12 2022-01-13         1003   Pierce Glover  pierce@email.com          12
#
#    brand  next_action  delivery_date  delivery_route  account_manager
# 0    ABC          NaN            NaN             NaN              NaN
# 3    ABC          NaN            NaN             NaN              NaN
# 4    ABC          NaN            NaN             NaN              NaN
# ...

# %%
orders[orders['product_id'] >12 ]
# Out:
#    order_date  customer_id            name             email  product_id  \
# 1  2022-01-02         1002     Jorden Haas  jorden@email.com          13
# 2  2022-01-03         1001      John Adams    john@email.com          13
# 3  2022-01-04         1002     Jorden Haas  jorden@email.com          14
# 5  2022-01-06         1001      John Adams    john@email.com          14
# 6  2022-01-07         1002     Jorden Haas  jorden@email.com          14
# 7  2022-01-08         1003   Pierce Glover  pierce@email.com          13
# 10 2022-01-11         1003   Pierce Glover  pierce@email.com          13
# 11 2022-01-12         1004  Carly Copeland               NaN          15
# 13 2022-01-14         1004  Carly Copeland               NaN          15
#
#      brand  next_action  delivery_date  delivery_route  account_manager
# 1   Brand2          NaN            NaN             NaN              NaN
# 2   Brand2          NaN            NaN             NaN              NaN
# ...

# %%
orders[(orders['brand'] == 'ABC') & (orders['order_date'] < '2022-01-08 00:00:00')]
# Out:
#   order_date  customer_id           name             email  product_id brand  \
# 0 2022-01-01         1001     John Adams    john@email.com          12   ABC
# 3 2022-01-04         1002    Jorden Haas  jorden@email.com          14   ABC
# 4 2022-01-05         1003  Pierce Glover  pierce@email.com          12   ABC
# 5 2022-01-06         1001     John Adams    john@email.com          14   ABC
# 6 2022-01-07         1002    Jorden Haas  jorden@email.com          14   ABC
#
#    next_action  delivery_date  delivery_route  account_manager
# 0          NaN            NaN             NaN              NaN
# 3          NaN            NaN             NaN              NaN
# 4          NaN            NaN             NaN              NaN
# 5          NaN            NaN             NaN              NaN
# 6          NaN            NaN             NaN              NaN

# %%
orders[orders['brand'].isin(['ABC','DT'])] # Use the isin() function for a list of conditions in the same column
# Out:
#    order_date  customer_id            name             email  product_id  \
# 0  2022-01-01         1001      John Adams    john@email.com          12
# 3  2022-01-04         1002     Jorden Haas  jorden@email.com          14
# 4  2022-01-05         1003   Pierce Glover  pierce@email.com          12
# 5  2022-01-06         1001      John Adams    john@email.com          14
# 6  2022-01-07         1002     Jorden Haas  jorden@email.com          14
# 8  2022-01-09         1004  Carly Copeland   carly@email.com          12
# 9  2022-01-10         1002     Jorden Haas  jorden@email.com          12
# 11 2022-01-12         1004  Carly Copeland               NaN          15
# 12 2022-01-13         1003   Pierce Glover  pierce@email.com          12
# 13 2022-01-14         1004  Carly Copeland               NaN          15
#
#    brand  next_action  delivery_date  delivery_route  account_manager
# 0    ABC          NaN            NaN             NaN              NaN
# ...

# %%
account_mgr = pd.read_csv('account_managers.csv')

# %%
account_mgr
# Out:
#     brand account_manager
# 0     ABC          Johnny
# 1  Brand2           Timmy
# 2      DT           Sammy

# %%
#There are two ways to connect 2 dataframe they are join() and merge()

# %%
merged_data=pd.merge(left = orders , right = account_mgr, left_on='brand', right_on='brand')

# %%
merged_data
# Out:
#    order_date  customer_id            name             email  product_id  \
# 0  2022-01-01         1001      John Adams    john@email.com          12
# 1  2022-01-04         1002     Jorden Haas  jorden@email.com          14
# 2  2022-01-05         1003   Pierce Glover  pierce@email.com          12
# 3  2022-01-06         1001      John Adams    john@email.com          14
# 4  2022-01-07         1002     Jorden Haas  jorden@email.com          14
# 5  2022-01-09         1004  Carly Copeland   carly@email.com          12
# 6  2022-01-10         1002     Jorden Haas  jorden@email.com          12
# 7  2022-01-13         1003   Pierce Glover  pierce@email.com          12
# 8  2022-01-02         1002     Jorden Haas  jorden@email.com          13
# 9  2022-01-03         1001      John Adams    john@email.com          13
# 10 2022-01-08         1003   Pierce Glover  pierce@email.com          13
# 11 2022-01-11         1003   Pierce Glover  pierce@email.com          13
# ...

# %%
account_mgr.set_index('brand',inplace=True) #Set permanently for the brand column to be indexed
joined_data = orders.set_index('brand').join(account_mgr, rsuffix='_x') #suffix basically add a suffix to the column name because otherwise the will have column with same name

# %%
joined_data
# Out:
#        order_date  customer_id            name             email  product_id  \
# brand
# ABC    2022-01-01         1001      John Adams    john@email.com          12
# ABC    2022-01-04         1002     Jorden Haas  jorden@email.com          14
# ABC    2022-01-05         1003   Pierce Glover  pierce@email.com          12
# ABC    2022-01-06         1001      John Adams    john@email.com          14
# ABC    2022-01-07         1002     Jorden Haas  jorden@email.com          14
# ABC    2022-01-09         1004  Carly Copeland   carly@email.com          12
# ABC    2022-01-10         1002     Jorden Haas  jorden@email.com          12
# ABC    2022-01-13         1003   Pierce Glover  pierce@email.com          12
# Brand2 2022-01-02         1002     Jorden Haas  jorden@email.com          13
# Brand2 2022-01-03         1001      John Adams    john@email.com          13
# Brand2 2022-01-08         1003   Pierce Glover  pierce@email.com          13
# ...

# %%
#if do not want to specify the rsuffix, can specify drop first then join. Should work
joined_data_v2 = orders.reset_index().set_index('brand').drop('account_manager',axis=1).join(account_mgr)

# %%
joined_data_v2
# Out:
#         index order_date  customer_id            name             email  \
# brand
# ABC         0 2022-01-01         1001      John Adams    john@email.com
# ABC         3 2022-01-04         1002     Jorden Haas  jorden@email.com
# ABC         4 2022-01-05         1003   Pierce Glover  pierce@email.com
# ABC         5 2022-01-06         1001      John Adams    john@email.com
# ABC         6 2022-01-07         1002     Jorden Haas  jorden@email.com
# ABC         8 2022-01-09         1004  Carly Copeland   carly@email.com
# ABC         9 2022-01-10         1002     Jorden Haas  jorden@email.com
# ABC        12 2022-01-13         1003   Pierce Glover  pierce@email.com
# Brand2      1 2022-01-02         1002     Jorden Haas  jorden@email.com
# Brand2      2 2022-01-03         1001      John Adams    john@email.com
# Brand2      7 2022-01-08         1003   Pierce Glover  pierce@email.com
# Brand2     10 2022-01-11         1003   Pierce Glover  pierce@email.com
# ...
